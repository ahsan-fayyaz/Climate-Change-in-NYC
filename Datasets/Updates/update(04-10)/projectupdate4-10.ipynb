# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
sv = pd.read_csv('/home/ahsan/Spring2019/csc217/Project/Temperature_data/Full_temp.csv',header=0)
sv
# Out:
#      YEAR   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV  \
# 0    1869  35.1  34.5  34.8  49.2  57.7  69.3  72.8  71.8  65.6  50.9  40.3
# 1    1870  37.5  31.3  34.1  50.7  60.9  72.9  76.6  75.3  67.6  56.7  45.5
# 2    1871  28.3  30.2  44.2  52.0  60.4  68.2  72.3  73.6  60.8  55.6  38.8
# 3    1872  28.8  29.9  30.5  49.4  61.5  71.2  77.5  75.6  66.4  53.2  41.0
# 4    1873  28.6  29.5  35.7  46.7  58.8  70.3  75.4  72.0  65.4  55.8  37.0
# 5    1874  34.2  31.3  37.1  41.1  58.8  70.1  73.9  70.3  67.0  55.1  43.4
# 6    1875  23.8  25.2  34.1  43.1  60.1  69.2  74.0  72.9  64.0  53.6  39.3
# 7    1876  36.6  31.8  34.4  47.0  60.2  73.5  79.4  75.2  63.7  50.6  45.2
# 8    1877  27.7  37.0  35.8  47.7  59.6  70.2  75.0  75.4  66.9  55.8  44.5
# 9    1878  30.3  32.2  44.1  53.3  59.4  67.7  77.8  74.2  68.3  58.7  43.8
# 10   1879  26.9  28.0  40.0  48.4  63.3  70.2  75.0  72.0  63.3  60.3  43.4
# ...

# %%
sv.shape
# Out:
# (150, 14)

# %%
sv.columns
# Out:
# Index(['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP',
#        'OCT', 'NOV', 'DEC', 'ANNUAL'],
#       dtype='object')

# %%
sv.dtypes
# Out:
# YEAR        int64
# JAN       float64
# FEB       float64
# MAR       float64
# APR       float64
# MAY       float64
# JUN       float64
# JUL       float64
# AUG       float64
# SEP       float64
# OCT       float64
# NOV       float64
# DEC       float64
# ANNUAL    float64
# dtype: object

# %%
#Plot a Swarmplot
fig1 = plt.figure(figsize=(10,10))
sns.swarmplot(data=sv['DEC'])

# %%
fig2 = plt.figure(figsize=(10,10))
plt.hist(sv['JUN'])
# Out:
# (array([ 2.,  1.,  8., 15., 20., 38., 28., 23., 12.,  3.]),
#  array([64.2, 65.4, 66.6, 67.8, 69. , 70.2, 71.4, 72.6, 73.8, 75. , 76.2]),
#  <a list of 10 Patch objects>)

# %%
fig3 = plt.figure(figsize=(10,10))
plt.boxplot(sv['JUN'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f54ac7aad68>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f54ac7b4438>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f54ac7aa940>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f54ac7b4ac8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f54ac7b4e10>],
#  'means': []}

# %%
np.mean(sv['JUN'])
# Out:
# 71.00999999999999

# %%
np.median(sv['JUN'])
# Out:
# 71.1

# %%
max = np.max(sv['JUN'])
max
# Out:
# 76.2

# %%
min = np.min(sv['JUN'])
min
# Out:
# 64.2

# %%
max - min
# Out:
# 12.0

# %%
var = np.var(sv['JUN'])
var
# Out:
# 4.6772999999999945

# %%
math.sqrt(var)
# Out:
# 2.162706637526226

# %%
np.percentile(sv['JUN'], q=75)
# Out:
# 72.65

# %%
plt.scatter(sv['YEAR'], sv['JUN'])

# %%
sv.plot.bar(x='YEAR', y='JUN')

# %% [markdown]
# ## THIS ALONE SHOWS JUN TEMPERATURES HAVE INCREASED OVER TIME

# %%
plt.plot(sv['JUN'])

# %% [markdown]
# ### The next data is for the Monthly and annual snowfall for Central Park

# %%
tf = pd.read_csv('/home/ahsan/Spring2019/csc217/Project/Snowfall_data/Snow_Full.csv',header=0)
tf
# Out:
#        SEASON  JUL  AUG  SEP  OCT  NOV   DEC   JAN   FEB   MAR   APR  MAY  \
# 0    1869-70   0.0  0.0  0.0    0    0   5.3   1.1   9.3   9.6   2.5    0
# 1    1870-71   0.0  0.0  0.0    0    0     3  15.9  12.1   0.1     2    0
# 2    1871-72   0.0  0.0  0.0    0  0.3   3.9   1.8     3   5.1    T     0
# 3    1872-73   0.0  0.0  0.0    0  3.5    27  10.6  18.8   0.4     0    0
# 4    1873-74   0.0  0.0  0.0    0    2   9.3   6.6    19    T      0    0
# 5    1874-75   0.0  0.0  0.0    0    0    10  14.5   4.5  15.3  13.5    0
# 6    1875-76   0.0  0.0  0.0    0    0   0.5   1.5  12.5   3.8     0    0
# 7    1876-77   0.0  0.0  0.0  0.5  0.1  12.4  20.5   0.4   6.5     0    0
# 8    1877-78   0.0  0.0  0.0    0    0     0   6.1     2     0     0    0
# 9    1878-79   0.0  0.0  0.0    0  0.1   5.5  17.3  11.3   1.5     0    0
# 10   1879-80   0.0  0.0  0.0    0  2.5   5.4   2.5     4   8.3     0    0
# 11   1880-81   0.0  0.0  0.0    0  1.4  11.5  11.5   8.8   2.3     0    0
# ...

# %%
tf.shape
# Out:
# (150, 14)

# %%
tf.dtypes
# Out:
# SEASON     object
# JUL       float64
# AUG       float64
# SEP       float64
# OCT        object
# NOV        object
# DEC        object
# JAN        object
# FEB        object
# MAR        object
# APR        object
# MAY        object
# JUN       float64
# TOTAL     float64
# dtype: object

# %%
fig_snow = plt.figure(figsize=(10,10))
sns.swarmplot(data=tf['TOTAL'])

# %%
fig2 = plt.figure(figsize=(10,10))
plt.hist(tf['TOTAL'])
# Out:
# /home/ahsan/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/ahsan/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([10., 30., 25., 29., 18., 14., 14.,  6.,  2.,  1.]),
#  array([ 2.8 , 10.08, 17.36, 24.64, 31.92, 39.2 , 46.48, 53.76, 61.04,
#         68.32, 75.6 ]),
#  <a list of 10 Patch objects>)

# %%
np.mean(tf['TOTAL'])
# Out:
# 28.888590604026838

# %% [markdown]
# ## Here are some visualizations

# %%
tf.plot.bar(x='SEASON', y='TOTAL')

# %%
tf.head().plot.bar(x='SEASON', y='TOTAL')

# %%
plt.plot(tf['TOTAL'])
